# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Exploratory Data Analysis

# %%
df = pd.read_csv("data/ifood_df.csv")
df.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2205.000000  2205.000000  2205.000000  2205.000000  2205.000000
# mean    51622.094785     0.442177     0.506576    49.009070   306.164626
# std     20713.063826     0.537132     0.544380    28.932111   337.493839
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35196.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51287.000000     0.000000     0.000000    49.000000   178.000000
# 75%     68281.000000     1.000000     1.000000    74.000000   507.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2205.000000      2205.000000      2205.000000       2205.000000
# mean     26.403175       165.312018        37.756463         27.128345
# std      39.784484       217.784507        54.824635         41.130468
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2205 entries, 0 to 2204
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Income                2205 non-null   float64
#  1   Kidhome               2205 non-null   int64
#  2   Teenhome              2205 non-null   int64
#  3   Recency               2205 non-null   int64
#  4   MntWines              2205 non-null   int64
#  5   MntFruits             2205 non-null   int64
#  6   MntMeatProducts       2205 non-null   int64
#  7   MntFishProducts       2205 non-null   int64
#  8   MntSweetProducts      2205 non-null   int64
#  9   MntGoldProds          2205 non-null   int64
#  10  NumDealsPurchases     2205 non-null   int64
#  11  NumWebPurchases       2205 non-null   int64
#  12  NumCatalogPurchases   2205 non-null   int64
#  13  NumStorePurchases     2205 non-null   int64
#  14  NumWebVisitsMonth     2205 non-null   int64
# ...

# %% [markdown]
# ## Are there any null values or outliers?

# %%
df.isna().sum()
# Out:
# Income                  0
# Kidhome                 0
# Teenhome                0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# Age                     0
# Customer_Days           0
# marital_Divorced        0
# marital_Married         0
# marital_Single          0
# marital_Together        0
# marital_Widow           0
# education_2n Cycle      0
# education_Basic         0
# education_Graduation    0
# education_Master        0
# ...

# %%
df_to_plot = df.drop(columns=["AcceptedCmpOverall","AcceptedCmp1", "AcceptedCmp2", "AcceptedCmp3","AcceptedCmp4", "AcceptedCmp5","Complain", "Response", "marital_Divorced", "marital_Married", "marital_Single", "marital_Together", "marital_Widow", "Z_CostContact", "education_2n Cycle","education_Basic", "education_Graduation","education_Master","education_PhD"])
df_to_plot.shape
# Out:
# (2205, 20)

# %%
df_to_plot.plot(subplots=True, layout=(5, 4), kind="box", figsize=(16, 20), patch_artist=True)
plt.subplots_adjust(wspace=0.5)

# %% [markdown]
# ## Removing Outlier Values with Modified Z score

# %%
sns.boxplot(df.MntRegularProds)
# Out:
# <Axes: ylabel='MntRegularProds'>

# %%
def get_mad(s):
    median = np.median(s)
    diff = abs(s - median)
    MAD = np.median(diff)
    return MAD

MAD = get_mad(df.MntRegularProds)
median = np.median(df.MntRegularProds)
MAD, median
# Out:
# (270.0, 288.0)

# %%
def get_modified_z_score(x, median, MAD):
    return 0.6745 * (x - median) / MAD

# %%
df["mod_z_score"] = df.MntRegularProds.apply(lambda x: get_modified_z_score(x, median, MAD))

# %%
df.customer
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3248\444717500.py in ?()
# ----> 1 df.customer
#
# C:\data_science_projects\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'customer'

# %%
new_df = df[df.mod_z_score < 3.5]

# %%
sns.boxplot(new_df.MntRegularProds)
# Out:
# <Axes: ylabel='MntRegularProds'>

# %%
new_df.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2112.000000  2112.000000  2112.000000  2112.000000  2112.000000
# mean    50319.655303     0.460701     0.523674    48.834280   275.028409
# std     20044.442880     0.540513     0.545780    28.979697   304.716287
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     34584.750000     0.000000     0.000000    24.000000    22.750000
# 50%     49939.500000     0.000000     0.000000    49.000000   162.000000
# 75%     66098.250000     1.000000     1.000000    74.000000   456.000000
# max    113734.000000     2.000000     2.000000    99.000000  1486.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2112.000000      2112.000000      2112.000000       2112.000000
# mean     24.359375       142.193655        34.586648         24.922822
# std      37.849638       185.991366        51.910201         39.141549
# ...

# %%
sns.boxplot(new_df.Income)
# Out:
# <Axes: ylabel='Income'>

# %%
new_df["modified_z_score2"] = new_df.Income.apply(lambda x: get_modified_z_score(x, np.median(new_df.Income), get_mad(new_df.Income)))
# Out:
# C:\Users\caner\AppData\Local\Temp\ipykernel_3248\1078053241.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["modified_z_score2"] = new_df.Income.apply(lambda x: get_modified_z_score(x, np.median(new_df.Income), get_mad(new_df.Income)))

# %%
new_df[new_df.modified_z_score2 > 2.5]
# Out:
#         Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 1872  113734.0        0         0        9         6          2
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 1872                3                1               262             3  ...
#
#       education_2n Cycle  education_Basic  education_Graduation  \
# 1872                   0                0                     0
#
#       education_Master  education_PhD  MntTotal  MntRegularProds  \
# 1872                 0              1       274              271
#
#       AcceptedCmpOverall  mod_z_score  modified_z_score2
# 1872                   0    -0.042469           2.732806
#
# [1 rows x 41 columns]

# %%
new_df = new_df[new_df.modified_z_score2 < 2.5]

# %%
sns.boxplot(new_df.Income)
# Out:
# <Axes: ylabel='Income'>

# %% [markdown]
# # Statistical Analysis and Data Visualization

# %% [markdown]
# # Distribution of NumStorePurchases

# %%
sns.histplot(new_df.NumStorePurchases, kde=True)
# Out:
# <Axes: xlabel='NumStorePurchases', ylabel='Count'>

# %%
new_df.head()
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  education_2n Cycle  \
# 0              172                88            88  ...                   0
# 1                2                 1             6  ...                   0
# 2              111                21            42  ...                   0
# 3               10                 3             5  ...                   0
# 4               46                27            15  ...                   0
#
# ...

# %% [markdown]
# ## Correlation with NumStorePurchases

# %%
sns.lmplot(data=new_df, x="MntMeatProducts", y="NumStorePurchases")
